# %% [markdown]
# <a href="https://colab.research.google.com/github/Supet1337/laba4dataset/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
#https://ru.wikipedia.org/wiki/Список_государств_и_зависимых_территорий_по_населению
df = pd.read_csv('/content/annual_deaths_by_causes.csv', sep=',')

# %%
#Вывод таблицы
df.head()
# Out:
#        country code  year  meningitis  alzheimer's_diesease  \
# 0  Afghanistan  AFG  2007   2933.0000             1402.0000
# 1  Afghanistan  AFG  2008   2731.0000             1424.0000
# 2  Afghanistan  AFG  2009   2460.0000             1449.0000
# 3  Afghanistan  AFG  2011   2327.0000             1508.0000
# 4  Afghanistan  AFG  2012   2254.0000             1544.0000
#
#    parkinson's_disease  nutritional_deficiency  malaria  drowning  \
# 0             450.0000               2488.0000 393.0000 2127.0000
# 1             455.0000               2277.0000 255.0000 1973.0000
# 2             460.0000               2040.0000 239.0000 1852.0000
# 3             473.0000               1846.0000 390.0000 1775.0000
# 4             482.0000               1705.0000  94.0000 1716.0000
#
#    interpersonal_violence  ...  chronic_kidney_disease  poisonings  \
# 0               3657.0000  ...               4490.0000    512.0000
# 1               3785.0000  ...               4534.0000    495.0000
# 2               3874.0000  ...               4597.0000    483.0000
# 3               4170.0000  ...               4785.0000    483.0000
# 4               4245.0000  ...               4846.0000    482.0000
#
#    protein_energy_malnutrition  terrorism  road_injuries  \
# 0                    2439.0000  1199.0000      7425.0000
# 1                    2231.0000  1092.0000      7355.0000
# 2                    1998.0000  1065.0000      7290.0000
# 3                    1805.0000  1525.0000      7432.0000
# 4                    1667.0000  3521.0000      7494.0000
#
#    chronic_respiratory_diseases  chronic_liver_diseases  digestive_diseases  \
# 0                     7222.0000               3346.0000           6458.0000
# 1                     7143.0000               3316.0000           6408.0000
# 2                     7045.0000               3291.0000           6358.0000
# 3                     6916.0000               3318.0000           6370.0000
# 4                     6878.0000               3353.0000           6398.0000
#
#    fire_heat_hot_substance  acute_hepatitis
# 0                 481.0000        3437.0000
# 1                 462.0000        3005.0000
# 2                 448.0000        2663.0000
# 3                 448.0000        2365.0000
# 4                 445.0000        2264.0000
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Data columns (total 35 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               7273 non-null   object
#  1   code                                  6206 non-null   object
#  2   year                                  7273 non-null   int64
#  3   meningitis                            6840 non-null   float64
#  4   alzheimer's_diesease                  6840 non-null   float64
#  5   parkinson's_disease                   6840 non-null   float64
#  6   nutritional_deficiency                6840 non-null   float64
#  7   malaria                               6840 non-null   float64
#  8   drowning                              6840 non-null   float64
#  9   interpersonal_violence                6840 non-null   float64
#  10  maternal_disorders                    6840 non-null   float64
#  11  hiv/aids                              6840 non-null   float64
#  12  drug_use_disorders                    6840 non-null   float64
#  13  tuberculosis                          6840 non-null   float64
#  14  cardiovascular_diseases               6840 non-null   float64
#  15  lower_respiratory_infections          6840 non-null   float64
#  16  neonatal_disorders                    6840 non-null   float64
#  17  alcohol_use_disorders                 6840 non-null   float64
#  18  self_harm                             6840 non-null   float64
#  19  exposure_to_forces_of_nature          6840 non-null   float64
#  20  diarrheal_diseases                    6840 non-null   float64
#  21  environmental_heat_and_cold_exposure  6840 non-null   float64
#  22  neoplasms                             6840 non-null   float64
#  23  conflict_and_terrorism                6840 non-null   float64
#  24  diabetes_mellitus                     6840 non-null   float64
#  25  chronic_kidney_disease                6840 non-null   float64
#  26  poisonings                            6840 non-null   float64
#  27  protein_energy_malnutrition           6840 non-null   float64
#  28  terrorism                             2891 non-null   float64
#  29  road_injuries                         6840 non-null   float64
#  30  chronic_respiratory_diseases          6840 non-null   float64
#  31  chronic_liver_diseases                6840 non-null   float64
#  32  digestive_diseases                    6840 non-null   float64
#  33  fire_heat_hot_substance               6840 non-null   float64
#  34  acute_hepatitis                       6840 non-null   float64
# dtypes: float64(32), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
#Описание таблицы
df.describe().loc[['count','min', 'max', 'mean']].T
# Out:
#                                        count     min         max  \
# year                                  7273.0  1990.0      2019.0
# meningitis                            6840.0     0.0    432524.0
# alzheimer's_diesease                  6840.0     0.0   1623276.0
# parkinson's_disease                   6840.0     0.0    362907.0
# nutritional_deficiency                6840.0     0.0    757152.0
# malaria                               6840.0     0.0    961129.0
# drowning                              6840.0     0.0    460665.0
# interpersonal_violence                6840.0     0.0    463129.0
# maternal_disorders                    6840.0     0.0    302586.0
# hiv/aids                              6840.0     0.0   1844490.0
# drug_use_disorders                    6840.0     0.0    128083.0
# tuberculosis                          6840.0     0.0   1808478.0
# cardiovascular_diseases               6840.0     4.0  18562510.0
# lower_respiratory_infections          6840.0     0.0   3320008.0
# neonatal_disorders                    6840.0     0.0   3005945.0
# alcohol_use_disorders                 6840.0     0.0    181768.0
# self_harm                             6840.0     0.0    841164.0
# exposure_to_forces_of_nature          6840.0     0.0    248861.0
# diarrheal_diseases                    6840.0     0.0   2904396.0
# environmental_heat_and_cold_exposure  6840.0     0.0     72653.0
# neoplasms                             6840.0     1.0  10079637.0
# conflict_and_terrorism                6840.0     0.0    566518.0
# diabetes_mellitus                     6840.0     1.0   1551170.0
# chronic_kidney_disease                6840.0     0.0   1427232.0
# poisonings                            6840.0     0.0     92101.0
# protein_energy_malnutrition           6840.0     0.0    656314.0
# terrorism                             2891.0     0.0     44490.0
# road_injuries                         6840.0     0.0   1285039.0
# chronic_respiratory_diseases          6840.0     1.0   3974315.0
# chronic_liver_diseases                6840.0     0.0   1472012.0
# digestive_diseases                    6840.0     0.0   2557689.0
# fire_heat_hot_substance               6840.0     0.0    129705.0
# acute_hepatitis                       6840.0     0.0    166405.0
#
#                                                mean
# year                                    2004.425134
# meningitis                              8213.149561
# alzheimer's_diesease                   27363.188158
# parkinson's_disease                     6493.627339
# nutritional_deficiency                 11006.353947
# malaria                                18903.160234
# drowning                                8619.055117
# interpersonal_violence                 10636.648684
# maternal_disorders                      6131.066959
# hiv/aids                               28141.249415
# drug_use_disorders                      2449.070760
# tuberculosis                           37153.226608
# cardiovascular_diseases               391007.961404
# lower_respiratory_infections           69343.833187
# neonatal_disorders                     61315.166813
# alcohol_use_disorders                   4247.575000
# self_harm                              20775.570760
# exposure_to_forces_of_nature            1178.546345
# diarrheal_diseases                     53212.579386
# environmental_heat_and_cold_exposure    1535.191813
# neoplasms                             206852.320614
# conflict_and_terrorism                  2439.892544
# diabetes_mellitus                      27143.007018
# chronic_kidney_disease                 25068.928801
# poisonings                              2145.455848
# protein_energy_malnutrition             9531.528801
# terrorism                                349.235905
# road_injuries                          30634.956140
# chronic_respiratory_diseases           91303.897661
# chronic_liver_diseases                 31898.919006
# digestive_diseases                     56525.512135
# fire_heat_hot_substance                 3006.043275
# acute_hepatitis                         3112.066520

# %%
print(df.loc[df['year'] == 1992, ['self_harm']].sum())
self_harm_count_all_df = pd.DataFrame(columns=['year', 'self_harm_count'])

for i in range(1990, 2020):
  self_harm_count_all_df.loc[len(self_harm_count_all_df)] = [i, *list(df.loc[df['year'] == i, ['self_harm']].sum()) ]


self_harm_count_all_df
#ГОД
# Out:
# self_harm    4636346.0
# dtype: float64
#       year  self_harm_count
# 0   1990.0        4454415.0
# 1   1991.0        4534944.0
# 2   1992.0        4636346.0
# 3   1993.0        4761812.0
# 4   1994.0        4910835.0
# 5   1995.0        4953819.0
# 6   1996.0        4914585.0
# 7   1997.0        4929454.0
# 8   1998.0        4974952.0
# 9   1999.0        5038830.0
# 10  2000.0        5026094.0
# 11  2001.0        4915541.0
# 12  2002.0        4858346.0
# 13  2003.0        4879357.0
# 14  2004.0        4906310.0
# 15  2005.0        4947871.0
# 16  2006.0        4876509.0
# 17  2007.0        4807665.0
# 18  2008.0        4779646.0
# 19  2009.0        4712726.0
# 20  2010.0        4703782.0
# 21  2011.0        4659531.0
# 22  2012.0        4596260.0
# 23  2013.0        4525456.0
# 24  2014.0        4457410.0
# 25  2015.0        4438763.0
# 26  2016.0        4437460.0
# 27  2017.0        4438242.0
# 28  2018.0        4504680.0
# 29  2019.0        4523263.0

# %% [markdown]
# Количество самоубийств за все года

# %%
plt.figure(figsize=(20,15))
sns.barplot(x="year",y="self_harm_count",data=self_harm_count_all_df)
plt.title('Количество самоубийств по миру')
plt.ylabel('Количество самоубийств в млн.')
plt.xlabel('Год')
#Поправить легенду
# Out:
# Text(0.5, 0, 'Год')

# %% [markdown]
# Количество самоубийств в России за 2019 г.

# %%
df.loc[((df['country'] == 'Russia') & (df['year'] == 2019)), ['country', 'self_harm', 'year']]
# Out:
#      country  self_harm  year
# 5149  Russia    39040.0  2019

# %% [markdown]
# Количество самоубийств в России за все года

# %%
self_harm_russia_df = pd.DataFrame(columns=['country', 'self_harm', 'year'])

for i in range(1990, 2020):
  self_harm_russia_df = self_harm_russia_df.append(df.loc[((df['country'] == 'Russia') & (df['year'] == i)), ['country', 'self_harm', 'year']])
  
self_harm_russia_df.reset_index(inplace = True)
self_harm_russia_df
# Out:
#     index country  self_harm  year
# 0    5120  Russia    46396.0  1990
# 1    5121  Russia    49054.0  1991
# 2    5122  Russia    57273.0  1992
# 3    5123  Russia    73110.0  1993
# 4    5124  Russia    83237.0  1994
# 5    5125  Russia    79951.0  1995
# 6    5126  Russia    73398.0  1996
# 7    5127  Russia    66834.0  1997
# 8    5128  Russia    65412.0  1998
# 9    5129  Russia    71781.0  1999
# 10   5130  Russia    74975.0  2000
# 11   5131  Russia    73928.0  2001
# 12   5132  Russia    73089.0  2002
# 13   5133  Russia    72826.0  2003
# 14   5134  Russia    70561.0  2004
# 15   5135  Russia    72826.0  2005
# 16   5136  Russia    65300.0  2006
# 17   5137  Russia    60280.0  2007
# 18   5138  Russia    58692.0  2008
# 19   5139  Russia    54325.0  2009
# 20   5140  Russia    53740.0  2010
# 21   5141  Russia    49407.0  2011
# 22   5142  Russia    47740.0  2012
# 23   5143  Russia    46665.0  2013
# 24   5144  Russia    47121.0  2014
# 25   5145  Russia    44710.0  2015
# 26   5146  Russia    42575.0  2016
# 27   5147  Russia    39829.0  2017
# 28   5148  Russia    39780.0  2018
# 29   5149  Russia    39040.0  2019

# %%
plt.figure(figsize=(10,4))
sns.lineplot(x="year",y="self_harm",data=self_harm_russia_df)
plt.title('Количество самоубийств за все года в России')
plt.ylabel('Количество самоубийств')
plt.xlabel('Год')
# Out:
# Text(0.5, 0, 'Год')

# %%
dfp = pd.read_csv('/content/poppulation.csv', sep=',', on_bad_lines='skip')
dfp['population'] = dfp['population'].astype('int')

unions = ['World', 'G20', 'World Bank Upper Middle Income', 'World Bank Lower Middle Income', 'World Bank Low Income', 'World Bank High Income', 'Western Pacific Region (WHO)', 'Western Europe', 'African Region (WHO)', 'East Asia & Pacific (WB)', 'South Asia (WB)', 'South-East Asia Region (WHO)', 'Sub-Saharan Africa (WB)','Eastern Mediterranean Region (WHO)', 'Europe & Central Asia (WB)', 'European Region (WHO)', 'Latin America & Caribbean (WB)', 'Middle East & North Africa (WB)','North America (WB)', 'OECD Countries', 'Region of the Americas (WHO)', 'South Africa', 'South Asia', 'Southeast Asia', 'United States Virgin Islands','South Asia (IDA & IBRD)', 'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income','Other small states', 'Pacific island small states', 'Post-demographic dividend', 'Pre-demographic dividend', 'Pre-demographic dividend', 'Middle East & North Africa (IDA & IBRD countries)', 'Middle income','Middle income', 'OECD members', 'Small states', 'Low income', 'Lower middle income', 'Middle East & North Africa', 'North America','Latin America & Caribbean (excluding high income)', 'Least developed countries: UN classification', 'Low & middle income', 'Middle East & North Africa (excluding high income)','IDA only', 'IDA total', 'Late-demographic dividend', 'Latin America & Caribbean', 'Latin America & the Caribbean (IDA & IBRD countries)','Heavily indebted poor countries (HIPC)', 'High income', 'IBRD only', 'IDA & IBRD total', 'IDA blend', 'Europe & Central Asia', 'Europe & Central Asia (excluding high income)', 'Europe & Central Asia (IDA & IBRD countries)', 'European Union', 'Fragile and conflict affected situations','Early-demographic dividend', 'East Asia & Pacific', 'East Asia & Pacific (excluding high income)', 'East Asia & Pacific (IDA & IBRD countries)', 'Euro area','Africa Eastern and Southern', 'Africa Western and Central', 'Arab World', 'Caribbean small states', 'Central Europe and the Baltics','West Bank and Gaza', 'West Bank and Gaza', 'Virgin Islands (U.S.)', 'Yugoslavia', 'Bosnia-Herzegovina', 'Australasia & Oceania', 'Central America & Caribbean',	'Central Asia','East Asia', 'Eastern Europe', 'Kosovo', 'South America', 'Aruba', 'Bahamas', 'Brunei', 'Brunei Darussalam', 'Cabo Verde', 'British Virgin Islands', 'Cayman Islands', 'Cape Verde', 'Channel Islands', 'Congo', 'Cook Islands', 'Curacao', 'Democratic Republic of Congo', 'Egypt', 'England', 'Faroe Islands', 'French Polynesia', 'Gambia', 'Gibraltar', 'Micronesia (country)','Liechtenstein', 'New Caledonia', 'Niue', 'North Korea', 'Northern Ireland', 'Palestine','Saint Kitts and Nevis','Saint Lucia',	'Saint Vincent and the Grenadines', 'Scotland', 'Sint Maarten (Dutch part)','South Korea', 'St. Kitts and Nevis', 'St. Lucia', 'St. Martin (French part)', 'St. Vincent and the Grenadines', 'Taiwan','Tokelau', 'Turks and Caicos Islands', 'Venezuela', 'Wales', 'Yemen']
          

dfp = dfp.loc[~dfp['country'].isin(unions), ['country', 'population']].sort_values(by='country', ascending=True)
dfp.reset_index(inplace = True, drop=True)
dfp
# Out:
#                       country  population
# 0                 Afghanistan    20170847
# 1                     Albania     3108778
# 2                     Algeria    30623406
# 3              American Samoa       57049
# 4                     Andorra       64368
# 5                      Angola    15866871
# 6         Antigua and Barbuda       74674
# 7                   Argentina    36467218
# 8                     Armenia     3089020
# 9                   Australia    18926000
# 10                    Austria     7992324
# 11                 Azerbaijan     7982750
# 12                    Bahrain      636540
# 13                 Bangladesh   125189655
# 14                   Barbados      270455
# 15                    Belarus    10026738
# 16                    Belgium    10226419
# 17                     Belize      238979
# 18                      Benin     6664102
# 19                    Bermuda       61285
# 20                     Bhutan      577886
# 21                    Bolivia     8257066
# 22     Bosnia and Herzegovina     3743353
# 23                   Botswana     1610260
# 24                     Brazil   172318674
# 25                   Bulgaria     8210624
# 26               Burkina Faso    11282696
# 27                    Burundi     6267132
# 28                   Cambodia    11886464
# 29                   Cameroon    15112598
# 30                     Canada    30401286
# 31   Central African Republic     3558019
# 32                       Chad     8053532
# 33                      Chile    15162801
# 34                      China  1252735000
# 35                   Colombia    38999468
# 36                    Comoros      528853
# 37                 Costa Rica     3885428
# 38              Cote d'Ivoire    16032573
# 39                    Croatia     4512597
# 40                       Cuba    11084673
# 41                     Cyprus      926049
# 42                    Czechia    10283860
# 43                    Denmark     5321799
# 44                   Djibouti      699973
# 45                   Dominica       69828
# 46         Dominican Republic     8343288
# 47                    Ecuador    12442109
# 48                El Salvador     5844834
# 49          Equatorial Guinea      581765
# 50                    Eritrea     2237412
# 51                    Estonia     1390244
# 52                   Eswatini      994105
# 53                   Ethiopia    64343008
# 54                       Fiji      806302
# 55                    Finland     5165474
# 56                     France    60496708
# 57                      Gabon     1199058
# 58                    Georgia     4157192
# 59                    Germany    82100243
# 60                      Ghana    18812369
# 61                     Greece    10761698
# 62                  Greenland       56100
# 63                    Grenada      102429
# 64                       Guam      153955
# 65                  Guatemala    11311078
# 66                     Guinea     8054745
# 67              Guinea-Bissau     1177133
# 68                     Guyana      749676
# 69                      Haiti     8319070
# 70                   Honduras     6397140
# 71                    Hungary    10237530
# 72                    Iceland      277381
# 73                      India  1038058154
# 74                  Indonesia   208615171
# 75                       Iraq    22802061
# 76                    Ireland     3754786
# 77                Isle of Man       75996
# 78                     Israel     6125000
# 79                      Italy    56916317
# 80                    Jamaica     2632677
# 81                      Japan   126631000
# 82                     Jordan     5031754
# 83                 Kazakhstan    14928374
# 84                      Kenya    31098763
# 85                   Kiribati       82969
# 86                     Kuwait     1951642
# 87            Kyrgyz Republic     4840400
# 88                    Lao PDR     5235339
# 89                     Latvia     2390482
# 90                    Lebanon     3747762
# 91                    Lesotho     2019732
# 92                    Liberia     2699708
# 93                      Libya     5275921
# 94                  Lithuania     3524238
# 95                 Luxembourg      430475
# 96                 Madagascar    15282524
# 97                     Malawi    10854325
# 98                   Malaysia    22661293
# 99                   Maldives      273522
# 100                      Mali    10642937
# 101                     Malta      387578
# 102          Marshall Islands       50418
# 103                Mauritania     2561584
# 104                 Mauritius     1175267
# 105                    Mexico    97484823
# 106                   Moldova     2929735
# 107                    Monaco       31836
# 108                  Mongolia     2376228
# 109                Montenegro      606001
# 110                   Morocco    28455504
# 111                Mozambique    17244176
# 112                   Myanmar    46181075
# 113                   Namibia     1763861
# 114                     Nauru       10449
# 115                     Nepal    23509971
# 116               Netherlands    15812088
# 117               New Zealand     3835100
# 118                 Nicaragua     4991041
# 119                     Niger    10929922
# 120                   Nigeria   119260055
# 121           North Macedonia     2017142
# 122  Northern Mariana Islands       55633
# 123                    Norway     4461913
# 124                      Oman     2254898
# 125                  Pakistan   138624625
# 126                     Palau       18773
# 127                    Panama     2971197
# 128          Papua New Guinea     5716166
# 129                  Paraguay     5216346
# 130                      Peru    26078295
# 131               Philippines    76325927
# 132                    Poland    38660271
# 133                  Portugal    10217828
# 134               Puerto Rico     3800081
# 135                     Qatar      570486
# 136                   Romania    22472040
# 137        Russian Federation   147214776
# 138                    Rwanda     7501238
# 139                     Samoa      173606
# 140                San Marino       27141
# 141     Sao Tome and Principe      139964
# 142              Saudi Arabia    20194531
# 143                   Senegal     9568717
# 144                    Serbia     7540401
# 145                Seychelles       80410
# 146              Sierra Leone     4462374
# 147                 Singapore     3958723
# 148           Slovak Republic     5396020
# 149                  Slovenia     1983045
# 150           Solomon Islands      401592
# 151                   Somalia     8553595
# 152               South Sudan     5933884
# 153                     Spain    40386875
# 154                 Sri Lanka    18663293
# 155                     Sudan    26626512
# 156                  Suriname      465380
# 157                    Sweden     8857874
# 158               Switzerland     7143991
# 159      Syrian Arab Republic    16013992
# 160                Tajikistan     6119664
# 161                  Tanzania    32682240
# 162                  Thailand    62298569
# 163               Timor-Leste      873138
# 164                      Togo     4780455
# 165                     Tonga       97475
# 166       Trinidad and Tobago     1263927
# 167                   Tunisia     9613587
# 168                   Turkiye    62287391
# 169              Turkmenistan     4466133
# 170                    Tuvalu        9344
# 171                    Uganda    22952406
# 172                   Ukraine    49674000
# 173      United Arab Emirates     2966029
# 174            United Kingdom    58682466
# 175             United States   279040000
# 176                   Uruguay     3308005
# 177                Uzbekistan    24311650
# 178                   Vanuatu      181259
# 179                   Vietnam    79035871
# 180                    Zambia    10140564
# 181                  Zimbabwe    11822722

# %%
self_harm_all_df = pd.DataFrame(columns=['country', 'self_harm'])


self_harm_all_df = self_harm_all_df.append(df.loc[ (df['year'] == 1999) & (~df['country'].isin(unions)) , ['country', 'self_harm']])

self_harm_all_df.reset_index(inplace = True, drop=True)

self_harm_all_df['self_harm'] = self_harm_all_df['self_harm'] / (dfp['population'] / 100)  

pd.set_option('display.float_format', '{:.4f}'.format)


self_harm_all_df.sort_values(by='country', ascending=True)
# Out:
#                       country  self_harm
# 0                 Afghanistan     0.0056
# 1                     Albania     0.0052
# 2                     Algeria     0.0052
# 3              American Samoa     0.0053
# 4                     Andorra     0.0109
# 5                      Angola     0.0076
# 6         Antigua and Barbuda     0.0027
# 7                   Argentina     0.0119
# 8                     Armenia     0.0041
# 9                   Australia     0.0141
# 10                    Austria     0.0199
# 11                 Azerbaijan     0.0027
# 12                    Bahrain     0.0068
# 13                 Bangladesh     0.0074
# 14                   Barbados     0.0052
# 15                    Belarus     0.0431
# 16                    Belgium     0.0227
# 17                     Belize     0.0067
# 18                      Benin     0.0062
# 19                    Bermuda     0.0049
# 20                     Bhutan     0.0062
# 21                    Bolivia     0.0067
# 22     Bosnia and Herzegovina     0.0106
# 23                   Botswana     0.0238
# 24                     Brazil     0.0062
# 25                   Bulgaria     0.0247
# 26               Burkina Faso     0.0074
# 27                    Burundi     0.0101
# 28                   Cambodia     0.0056
# 29                   Cameroon     0.0078
# 30                     Canada     0.0147
# 31   Central African Republic     0.0132
# 32                       Chad     0.0072
# 33                      Chile     0.0133
# 34                      China     0.0159
# 35                   Colombia     0.0059
# 36                    Comoros     0.0059
# 37                 Costa Rica     0.0071
# 38              Cote d'Ivoire     0.0092
# 39                    Croatia     0.0236
# 40                       Cuba     0.0193
# 41                     Cyprus     0.0054
# 42                    Czechia     0.0176
# 43                    Denmark     0.0182
# 44                   Djibouti     0.0050
# 45                   Dominica     0.0057
# 46         Dominican Republic     0.0053
# 47                    Ecuador     0.0065
# 48                El Salvador     0.0089
# 49          Equatorial Guinea     0.0077
# 50                    Eritrea     0.0147
# 51                    Estonia     0.0348
# 52                   Eswatini     0.0159
# 53                   Ethiopia     0.0094
# 54                       Fiji     0.0100
# 55                    Finland     0.0254
# 56                     France     0.0225
# 57                      Gabon     0.0113
# 58                    Georgia     0.0080
# 59                    Germany     0.0160
# 60                      Ghana     0.0055
# 61                     Greece     0.0040
# 62                  Greenland     0.0891
# 63                    Grenada     0.0049
# 64                       Guam     0.0162
# 65                  Guatemala     0.0072
# 66                     Guinea     0.0063
# 67              Guinea-Bissau     0.0093
# 68                     Guyana     0.0335
# 69                      Haiti     0.0077
# 70                   Honduras     0.0027
# 71                    Hungary     0.0322
# 72                    Iceland     0.0133
# 73                      India     0.0189
# 74                  Indonesia     0.0036
# 75                       Iran     0.0195
# 76                       Iraq     0.0325
# 77                    Ireland     0.6882
# 78                     Israel     0.0090
# 79                      Italy     0.0089
# 80                    Jamaica     0.0025
# 81                      Japan     0.0247
# 82                     Jordan     0.0029
# 83                 Kazakhstan     0.0326
# 84                      Kenya     0.0055
# 85                   Kiribati     0.0301
# 86                     Kuwait     0.0036
# 87                 Kyrgyzstan     0.0141
# 88                       Laos     0.0088
# 89                     Latvia     0.0359
# 90                    Lebanon     0.0033
# 91                    Lesotho     0.0197
# 92                    Liberia     0.0062
# 93                      Libya     0.0039
# 94                  Lithuania     0.0476
# 95                 Luxembourg     0.0160
# 96                 Madagascar     0.0064
# 97                     Malawi     0.0086
# 98                   Malaysia     0.0057
# 99                   Maldives     0.0048
# 100                      Mali     0.0050
# 101                     Malta     0.0057
# 102          Marshall Islands     0.0218
# 103                Mauritania     0.0046
# 104                 Mauritius     0.0135
# 105                    Mexico     0.0045
# 106                   Moldova     0.0259
# 107                    Monaco     0.0157
# 108                  Mongolia     0.0217
# 109                Montenegro     0.0211
# 110                   Morocco     0.0090
# 111                Mozambique     0.0067
# 112                   Myanmar     0.0063
# 113                   Namibia     0.0133
# 114                     Nauru     0.0287
# 115                     Nepal     0.0118
# 116               Netherlands     0.0117
# 117               New Zealand     0.0144
# 118                 Nicaragua     0.0059
# 119                     Niger     0.0045
# 120                   Nigeria     0.0048
# 121           North Macedonia     0.0109
# 122  Northern Mariana Islands     0.0180
# 123                    Norway     0.0135
# 124                      Oman     0.0034
# 125                  Pakistan     0.0081
# 126                     Palau     0.0160
# 127                    Panama     0.0059
# 128          Papua New Guinea     0.0028
# 129                  Paraguay     0.0041
# 130                      Peru     0.0034
# 131               Philippines     0.0038
# 132                    Poland     0.0207
# 133                  Portugal     0.0138
# 134               Puerto Rico     0.0083
# 135                     Qatar     0.0061
# 136                   Romania     0.0125
# 137                    Russia     0.0488
# 138                    Rwanda     0.0102
# 139                     Samoa     0.0144
# 140                San Marino     0.0111
# 141     Sao Tome and Principe     0.0021
# 142              Saudi Arabia     0.0026
# 143                   Senegal     0.0067
# 144                    Serbia     0.0312
# 145                Seychelles     0.0099
# 146              Sierra Leone     0.0053
# 147                 Singapore     0.0119
# 148                  Slovakia     0.0158
# 149                  Slovenia     0.0333
# 150           Solomon Islands     0.0242
# 151                   Somalia     0.0086
# 152               South Sudan     0.0058
# 153                     Spain     0.0092
# 154                 Sri Lanka     0.0398
# 155                     Sudan     0.0058
# 156                  Suriname     0.0219
# 157                    Sweden     0.0168
# 158               Switzerland     0.0216
# 159                     Syria     0.0019
# 160                Tajikistan     0.0043
# 161                  Tanzania     0.0067
# 162                  Thailand     0.0171
# 163                     Timor     0.0050
# 164                      Togo     0.0066
# 165                     Tonga     0.0051
# 166       Trinidad and Tobago     0.0143
# 167                   Tunisia     0.0038
# 168                    Turkey     0.0052
# 169              Turkmenistan     0.0109
# 170                    Tuvalu     0.0214
# 171                    Uganda     0.0074
# 172                   Ukraine     0.0360
# 173      United Arab Emirates     0.0067
# 174            United Kingdom     0.0102
# 175             United States     0.0122
# 176                   Uruguay     0.0174
# 177                Uzbekistan     0.0105
# 178                   Vanuatu     0.0199
# 179                   Vietnam     0.0075
# 180                    Zambia     0.0083
# 181                  Zimbabwe     0.0121

# %%
plt.figure(figsize=(20,90))
sns.barplot(x="self_harm", y="country",data=self_harm_all_df)
plt.title('Количество самоубийств за 1999 год в мире') 
plt.ylabel('Страна')
plt.xlabel('Процент самоубийств по отношению к населению за 1990г.')
# Out:
# Text(0.5, 0, 'Процент самоубийств по отношению к населению за 1990г.')

# %%
self_harm_all_df = pd.DataFrame(columns=['country', 'self_harm'])
self_harm_all_df = self_harm_all_df.append(df.loc[ (df['year'] == 1999) & (df['country'].isin(['China', 'India'])) , ['country', 'self_harm']])
  
self_harm_all_df.reset_index(inplace = True, drop=True)
self_harm_all_df


plt.figure(figsize=(20,4))
sns.barplot(x="self_harm", y="country",data=self_harm_all_df)
plt.title('Количество самоубийств за 1999 год в Китае и Индии') 
plt.ylabel('Страна')
plt.xlabel('Количество самоубийств')
# Out:
# Text(0.5, 1.0, 'Количество самоубийств за 1999 год в Китае и Индии')

# %%
aid_income_df = pd.DataFrame(columns=['country', 'hiv/aids'])

income = ['World Bank Upper Middle Income', 'World Bank Lower Middle Income', 'World Bank Low Income', 'World Bank High Income']

aid_income_df = aid_income_df.append(df.loc[ (df['year'] == 2019) & (df['country'].isin(income)) , ['country', 'hiv/aids']])
  
aid_income_df.reset_index(inplace = True, drop=True)
aid_income_df
# Out:
#                           country    hiv/aids
# 0          World Bank High Income  13795.0000
# 1           World Bank Low Income 247763.0000
# 2  World Bank Lower Middle Income 338846.0000
# 3  World Bank Upper Middle Income 262649.0000

# %%
plt.figure(figsize=(20,4))
sns.barplot(x="hiv/aids", y="country",data=aid_income_df)
plt.title('Количество смертей от спида за 2019 год в Странах с разным доходом')
plt.ylabel('Доход')
plt.xlabel('Количество смертей от спида')
# Out:
# Text(0.5, 0, 'Количество смертей от спида')

# %%
plt.figure(figsize=(90,40))
sns.barplot(data=df.loc[df['year'] == 2019,'meningitis':'acute_hepatitis'])
plt.title('Количество смертей по разным причинам за 2019г.') 
plt.ylabel('Количество смертей')
plt.xlabel('Причина')
# Out:
# Text(0.5, 0, 'Причина')
